# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('../datasets/train.csv')
df_test = pd.read_csv('../datasets/test.csv')
df_weather = pd.read_csv('../datasets/weather.csv')
df_spray = pd.read_csv('../datasets/spray.csv')

# %%
df_train.head(1)
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
#
#               AddressNumberAndStreet  Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
#
#    NumMosquitos  WnvPresent
# 0             1           0

# %%
df_test.head(1)
# Out:
#    Id        Date                                            Address  \
# 0   1  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
#
#               AddressNumberAndStreet  Latitude  Longitude  AddressAccuracy
# 0  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9

# %%
#Define function to conduct basic EDA
def eda(dataframe):
    """Runs basic EDA on dataframe."""
    print("missing values \n", dataframe.isnull().sum(), '\n')
    print("dataframe index \n", dataframe.index, '\n')
    print("dataframe types \n", dataframe.dtypes, '\n')
    print("dataframe shape \n", dataframe.shape, '\n')
    print("dataframe describe \n", dataframe.describe(include='all'), '\n')

# %%
eda(df_train)
# Out:
# missing values
#  Date                      0
# Address                   0
# Species                   0
# Block                     0
# Street                    0
# Trap                      0
# AddressNumberAndStreet    0
# Latitude                  0
# Longitude                 0
# AddressAccuracy           0
# NumMosquitos              0
# WnvPresent                0
# dtype: int64
#
# dataframe index
#  RangeIndex(start=0, stop=10506, step=1)
#
# dataframe types
#  Date                       object
# Address                    object
# Species                    object
# Block                       int64
# Street                     object
# Trap                       object
# AddressNumberAndStreet     object
# Latitude                  float64
# Longitude                 float64
# AddressAccuracy             int64
# NumMosquitos                int64
# WnvPresent                  int64
# dtype: object
#
# dataframe shape
#  (10506, 12)
#
# dataframe describe
#                Date                                            Address  \
# count        10506                                              10506
# unique          95                                                138
# top     2007-08-01  ORD Terminal 5, O'Hare International Airport, ...
# freq           551                                                750
# mean           NaN                                                NaN
# std            NaN                                                NaN
# min            NaN                                                NaN
# 25%            NaN                                                NaN
# 50%            NaN                                                NaN
# 75%            NaN                                                NaN
# max            NaN                                                NaN
#
#                        Species         Block            Street   Trap  \
# count                    10506  10506.000000             10506  10506
# unique                       7           NaN               128    136
# top     CULEX PIPIENS/RESTUANS           NaN   W OHARE AIRPORT   T900
# freq                      4752           NaN               750    750
# mean                       NaN     35.687797               NaN    NaN
# std                        NaN     24.339468               NaN    NaN
# min                        NaN     10.000000               NaN    NaN
# 25%                        NaN     12.000000               NaN    NaN
# 50%                        NaN     33.000000               NaN    NaN
# 75%                        NaN     52.000000               NaN    NaN
# max                        NaN     98.000000               NaN    NaN
#
#                     AddressNumberAndStreet      Latitude     Longitude  \
# count                                10506  10506.000000  10506.000000
# unique                                 138           NaN           NaN
# top     1000  W OHARE AIRPORT, Chicago, IL           NaN           NaN
# freq                                   750           NaN           NaN
# mean                                   NaN     41.841139    -87.699908
# std                                    NaN      0.112742      0.096514
# min                                    NaN     41.644612    -87.930995
# 25%                                    NaN     41.732984    -87.760070
# 50%                                    NaN     41.846283    -87.694991
# 75%                                    NaN     41.954690    -87.627796
# max                                    NaN     42.017430    -87.531635
#
#         AddressAccuracy  NumMosquitos    WnvPresent
# count      10506.000000  10506.000000  10506.000000
# unique              NaN           NaN           NaN
# top                 NaN           NaN           NaN
# freq                NaN           NaN           NaN
# mean           7.819532     12.853512      0.052446
# std            1.452921     16.133816      0.222936
# min            3.000000      1.000000      0.000000
# 25%            8.000000      2.000000      0.000000
# 50%            8.000000      5.000000      0.000000
# 75%            9.000000     17.000000      0.000000
# max            9.000000     50.000000      1.000000

# %%
eda(df_test)
# Out:
# missing values
#  Id                        0
# Date                      0
# Address                   0
# Species                   0
# Block                     0
# Street                    0
# Trap                      0
# AddressNumberAndStreet    0
# Latitude                  0
# Longitude                 0
# AddressAccuracy           0
# dtype: int64
#
# dataframe index
#  RangeIndex(start=0, stop=116293, step=1)
#
# dataframe types
#  Id                          int64
# Date                       object
# Address                    object
# Species                    object
# Block                       int64
# Street                     object
# Trap                       object
# AddressNumberAndStreet     object
# Latitude                  float64
# Longitude                 float64
# AddressAccuracy             int64
# dtype: object
#
# dataframe shape
#  (116293, 11)
#
# dataframe describe
#                     Id        Date  \
# count   116293.000000      116293
# unique            NaN          95
# top               NaN  2012-07-09
# freq              NaN        1293
# mean     58147.000000         NaN
# std      33571.041765         NaN
# min          1.000000         NaN
# 25%      29074.000000         NaN
# 50%      58147.000000         NaN
# 75%      87220.000000         NaN
# max     116293.000000         NaN
#
#                                                   Address  \
# count                                              116293
# unique                                                151
# top     ORD Terminal 5, O'Hare International Airport, ...
# freq                                                 1468
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                        Species          Block           Street    Trap  \
# count                   116293  116293.000000           116293  116293
# unique                       8            NaN              139     149
# top     CULEX PIPIENS/RESTUANS            NaN   N OAK PARK AVE    T009
# freq                     15359            NaN             1617    1528
# mean                       NaN      41.131100              NaN     NaN
# std                        NaN      24.864726              NaN     NaN
# min                        NaN      10.000000              NaN     NaN
# 25%                        NaN      18.000000              NaN     NaN
# 50%                        NaN      39.000000              NaN     NaN
# 75%                        NaN      61.000000              NaN     NaN
# max                        NaN      98.000000              NaN     NaN
#
#                     AddressNumberAndStreet       Latitude      Longitude  \
# count                               116293  116293.000000  116293.000000
# unique                                 151            NaN            NaN
# top     1000  W OHARE AIRPORT, Chicago, IL            NaN            NaN
# freq                                  1468            NaN            NaN
# mean                                   NaN      41.849389     -87.693658
# std                                    NaN       0.106593       0.080699
# min                                    NaN      41.644612     -87.930995
# 25%                                    NaN      41.753411     -87.750938
# 50%                                    NaN      41.862292     -87.694991
# 75%                                    NaN      41.951866     -87.648860
# max                                    NaN      42.017430     -87.531635
#
#         AddressAccuracy
# count     116293.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean           7.954357
# std            1.252733
# min            3.000000
# 25%            8.000000
# 50%            8.000000
# 75%            9.000000
# max            9.000000

# %% [markdown]
# Test data does not have the column 'NumMosquitos'

# %%
#Define function to get year and month from date
get_year = lambda x:x.split('-')[0]
get_month = lambda x:x.split('-')[1]

# %%
#Find year and month for train & test
df_train['Year'] = df_train['Date'].apply(get_year)
df_train['Month'] = df_train['Date'].apply(get_month)

df_test['Year'] = df_test['Date'].apply(get_year)
df_test['Month'] = df_test['Date'].apply(get_month)

# %%
#Find Satellite Trap in Train Data
for i in df_train['Trap'].value_counts().index:
    if len(i) == 5:
        print(i)
# Out:
# T054C
# T094B

# %%
#Find extra categories in Trap in Test data
for i in df_test['Trap'].value_counts().index:
    if i not in df_train['Trap'].value_counts().index:
        print(i)
# Out:
# T090A
# T065A
# T200A
# T218C
# T218B
# T002B
# T218A
# T090C
# T090B
# T200B
# T002A
# T234
# T128A

# %% [markdown]
# 'T234' is present in df_test['Trap'] but not df_train['Trap']

# %%
#convert all satellite trap to have the same trap name as parent trap
trap_rename = lambda x: x[0:4] if len(x)==5 else x
df_train['Trap'] = df_train['Trap'].apply(trap_rename)
df_test['Trap'] = df_test['Trap'].apply(trap_rename)

# %%
#Remove T in Trap name
remove_t = lambda x: x.replace('T','')
df_train['Trap'] = df_train['Trap'].apply(remove_t)
df_test['Trap'] = df_test['Trap'].apply(remove_t)

#Convert Trap type to int
df_train['Trap'] = df_train['Trap'].astype('int64',inplace=True)
df_test['Trap'] = df_test['Trap'].astype('int64',inplace=True)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10506 entries, 0 to 10505
# Data columns (total 14 columns):
# Date                      10506 non-null object
# Address                   10506 non-null object
# Species                   10506 non-null object
# Block                     10506 non-null int64
# Street                    10506 non-null object
# Trap                      10506 non-null int64
# AddressNumberAndStreet    10506 non-null object
# Latitude                  10506 non-null float64
# Longitude                 10506 non-null float64
# AddressAccuracy           10506 non-null int64
# NumMosquitos              10506 non-null int64
# WnvPresent                10506 non-null int64
# Year                      10506 non-null object
# Month                     10506 non-null object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.1+ MB

# %%
#Each row only has maximum 50 mosquito before a new row is created, need to sum up the total mosquito by species,
#trap,date and WnvPresent
df_train.groupby(['Date', 'Trap', 'Species','WnvPresent'], as_index=False)['NumMosquitos'].sum().sort_values(by='NumMosquitos').tail(3)
# Out:
#             Date  Trap        Species  WnvPresent  NumMosquitos
# 1481  2007-08-16   115  CULEX PIPIENS           0          2050
# 1954  2007-08-28   115  CULEX PIPIENS           0          2107
# 566   2007-07-25   115  CULEX PIPIENS           0          2206

# %%
#merge total mosquito with train data
df_train = pd.merge(df_train, df_train.groupby(['Date', 'Trap', 'Species','WnvPresent'], as_index=False)['NumMosquitos'].sum(), 
                    how='left', on=['Date', 'Trap', 'Species','WnvPresent'])
#rename column wich include total mosquito
df_train.columns = ['Date', 'Address', 'Species', 'Block', 'Street', 'Trap',
       'AddressNumberAndStreet', 'Latitude', 'Longitude', 'AddressAccuracy',
       'NumMosquitos', 'WnvPresent','Year','Month','Tot_Mos_Species']
df_train.head(1)
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE     2
#
#               AddressNumberAndStreet  Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
#
#    NumMosquitos  WnvPresent  Year Month  Tot_Mos_Species
# 0             1           0  2007    05                1

# %%
df_train[df_train.duplicated(subset=['Date', 'Trap', 'Species','Tot_Mos_Species','WnvPresent'],keep=False)]
# Out:
#              Date                                            Address  \
# 98     2007-06-26     2200 West 113th Street, Chicago, IL 60643, USA
# 99     2007-06-26     2200 West 113th Street, Chicago, IL 60643, USA
# 280    2007-07-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 281    2007-07-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 293    2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 294    2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 295    2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 296    2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 297    2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 298    2007-07-11     2200 West 113th Street, Chicago, IL 60643, USA
# 315    2007-07-11  3600 North Pittsburgh Avenue, Chicago, IL 6063...
# 316    2007-07-11  3600 North Pittsburgh Avenue, Chicago, IL 6063...
# 318    2007-07-11    7200 North Oketo Avenue, Chicago, IL 60631, USA
# 319    2007-07-11    7200 North Oketo Avenue, Chicago, IL 60631, USA
# 320    2007-07-11    7200 North Oketo Avenue, Chicago, IL 60631, USA
# 321    2007-07-11    7200 North Oketo Avenue, Chicago, IL 60631, USA
# 350    2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 351    2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 352    2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 353    2007-07-11     3500 West 116th Street, Chicago, IL 60655, USA
# 403    2007-07-11      2200 West 69th Street, Chicago, IL 60636, USA
# 404    2007-07-11      2200 West 69th Street, Chicago, IL 60636, USA
# 436    2007-07-18     2500 West Grand Avenue, Chicago, IL 60654, USA
# 437    2007-07-18     2500 West Grand Avenue, Chicago, IL 60654, USA
# 458    2007-07-18    7200 North Oketo Avenue, Chicago, IL 60631, USA
# 459    2007-07-18    7200 North Oketo Avenue, Chicago, IL 60631, USA
# 462    2007-07-18  4900 West Balmoral Avenue, Chicago, IL 60630, USA
# 463    2007-07-18  4900 West Balmoral Avenue, Chicago, IL 60630, USA
# 464    2007-07-18  5800 North Western Avenue, Chicago, IL 60659, USA
# 465    2007-07-18  5800 North Western Avenue, Chicago, IL 60659, USA
# ...           ...                                                ...
# 10259  2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 10260  2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 10261  2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 10262  2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 10264  2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 10265  2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 10266  2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 10267  2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 10268  2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 10269  2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 10270  2013-09-12  ORD Terminal 5, O'Hare International Airport, ...
# 10283  2013-09-12  1300 North Laramie Avenue, Chicago, IL 60651, USA
# 10284  2013-09-12  1300 North Laramie Avenue, Chicago, IL 60651, USA
# 10301  2013-09-12    2100 North Cannon Drive, Chicago, IL 60614, USA
# 10310  2013-09-19    2200 North Cannon Drive, Chicago, IL 60614, USA
# 10311  2013-09-19    2200 North Cannon Drive, Chicago, IL 60614, USA
# 10386  2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 10387  2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 10388  2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 10389  2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 10390  2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 10391  2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 10392  2013-09-19  ORD Terminal 5, O'Hare International Airport, ...
# 10413  2013-09-19    2100 North Cannon Drive, Chicago, IL 60614, USA
# 10442  2013-09-26  1100 South California Avenue, Chicago, IL 6061...
# 10443  2013-09-26  1100 South California Avenue, Chicago, IL 6061...
# 10486  2013-09-26  ORD Terminal 5, O'Hare International Airport, ...
# 10487  2013-09-26  ORD Terminal 5, O'Hare International Airport, ...
# 10488  2013-09-26  ORD Terminal 5, O'Hare International Airport, ...
# 10489  2013-09-26  ORD Terminal 5, O'Hare International Airport, ...
#
#                       Species  Block             Street  Trap  \
# 98     CULEX PIPIENS/RESTUANS     22         W 113TH ST    86
# 99     CULEX PIPIENS/RESTUANS     22         W 113TH ST    86
# 280            CULEX RESTUANS     79       W FOSTER AVE    15
# 281            CULEX RESTUANS     79       W FOSTER AVE    15
# 293    CULEX PIPIENS/RESTUANS     22         W 113TH ST    86
# 294    CULEX PIPIENS/RESTUANS     22         W 113TH ST    86
# 295    CULEX PIPIENS/RESTUANS     22         W 113TH ST    86
# 296    CULEX PIPIENS/RESTUANS     22         W 113TH ST    86
# 297            CULEX RESTUANS     22         W 113TH ST    86
# 298            CULEX RESTUANS     22         W 113TH ST    86
# 315            CULEX RESTUANS     36   N PITTSBURGH AVE    11
# 316            CULEX RESTUANS     36   N PITTSBURGH AVE    11
# 318    CULEX PIPIENS/RESTUANS     72        N OKETO AVE    16
# 319    CULEX PIPIENS/RESTUANS     72        N OKETO AVE    16
# 320            CULEX RESTUANS     72        N OKETO AVE    16
# 321            CULEX RESTUANS     72        N OKETO AVE    16
# 350    CULEX PIPIENS/RESTUANS     35         W 116TH ST   158
# 351    CULEX PIPIENS/RESTUANS     35         W 116TH ST   158
# 352    CULEX PIPIENS/RESTUANS     35         W 116TH ST   158
# 353    CULEX PIPIENS/RESTUANS     35         W 116TH ST   158
# 403            CULEX RESTUANS     22          W 69TH ST    69
# 404            CULEX RESTUANS     22          W 69TH ST    69
# 436    CULEX PIPIENS/RESTUANS     25        W GRAND AVE    46
# 437    CULEX PIPIENS/RESTUANS     25        W GRAND AVE    46
# 458    CULEX PIPIENS/RESTUANS     72        N OKETO AVE    16
# 459    CULEX PIPIENS/RESTUANS     72        N OKETO AVE    16
# 462    CULEX PIPIENS/RESTUANS     49     W BALMORAL AVE    25
# 463    CULEX PIPIENS/RESTUANS     49     W BALMORAL AVE    25
# 464            CULEX RESTUANS     58      N WESTERN AVE    28
# 465            CULEX RESTUANS     58      N WESTERN AVE    28
# ...                       ...    ...                ...   ...
# 10259  CULEX PIPIENS/RESTUANS     10    W OHARE AIRPORT   900
# 10260  CULEX PIPIENS/RESTUANS     10    W OHARE AIRPORT   900
# 10261  CULEX PIPIENS/RESTUANS     10    W OHARE AIRPORT   900
# 10262  CULEX PIPIENS/RESTUANS     10    W OHARE AIRPORT   900
# 10264           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10265           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10266           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10267           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10268           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10269           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10270           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10283           CULEX PIPIENS     13      N LARAMIE AVE   230
# 10284           CULEX PIPIENS     13      N LARAMIE AVE   230
# 10301           CULEX PIPIENS     21        N CANNON DR    54
# 10310           CULEX PIPIENS     22        N CANNON DR    54
# 10311           CULEX PIPIENS     22        N CANNON DR    54
# 10386  CULEX PIPIENS/RESTUANS     10    W OHARE AIRPORT   900
# 10387  CULEX PIPIENS/RESTUANS     10    W OHARE AIRPORT   900
# 10388  CULEX PIPIENS/RESTUANS     10    W OHARE AIRPORT   900
# 10389           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10390           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10391           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10392           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10413           CULEX PIPIENS     21        N CANNON DR    54
# 10442  CULEX PIPIENS/RESTUANS     11       S CALIFORNIA    47
# 10443  CULEX PIPIENS/RESTUANS     11       S CALIFORNIA    47
# 10486           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10487           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10488           CULEX PIPIENS     10    W OHARE AIRPORT   900
# 10489           CULEX PIPIENS     10    W OHARE AIRPORT   900
#
#                     AddressNumberAndStreet   Latitude  Longitude  \
# 98           2200  W 113TH ST, Chicago, IL  41.688324 -87.676709
# 99           2200  W 113TH ST, Chicago, IL  41.688324 -87.676709
# 280        7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 281        7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 293          2200  W 113TH ST, Chicago, IL  41.688324 -87.676709
# 294          2200  W 113TH ST, Chicago, IL  41.688324 -87.676709
# 295          2200  W 113TH ST, Chicago, IL  41.688324 -87.676709
# 296          2200  W 113TH ST, Chicago, IL  41.688324 -87.676709
# 297          2200  W 113TH ST, Chicago, IL  41.688324 -87.676709
# 298          2200  W 113TH ST, Chicago, IL  41.688324 -87.676709
# 315    3600  N PITTSBURGH AVE, Chicago, IL  41.944869 -87.832763
# 316    3600  N PITTSBURGH AVE, Chicago, IL  41.944869 -87.832763
# 318         7200  N OKETO AVE, Chicago, IL  42.011601 -87.811506
# 319         7200  N OKETO AVE, Chicago, IL  42.011601 -87.811506
# 320         7200  N OKETO AVE, Chicago, IL  42.011601 -87.811506
# 321         7200  N OKETO AVE, Chicago, IL  42.011601 -87.811506
# 350          3500  W 116TH ST, Chicago, IL  41.682587 -87.707973
# 351          3500  W 116TH ST, Chicago, IL  41.682587 -87.707973
# 352          3500  W 116TH ST, Chicago, IL  41.682587 -87.707973
# 353          3500  W 116TH ST, Chicago, IL  41.682587 -87.707973
# 403           2200  W 69TH ST, Chicago, IL  41.768388 -87.678649
# 404           2200  W 69TH ST, Chicago, IL  41.768388 -87.678649
# 436         2500  W GRAND AVE, Chicago, IL  41.891118 -87.654491
# 437         2500  W GRAND AVE, Chicago, IL  41.891118 -87.654491
# 458         7200  N OKETO AVE, Chicago, IL  42.011601 -87.811506
# 459         7200  N OKETO AVE, Chicago, IL  42.011601 -87.811506
# 462      4900  W BALMORAL AVE, Chicago, IL  41.979243 -87.750938
# 463      4900  W BALMORAL AVE, Chicago, IL  41.979243 -87.750938
# 464       5800  N WESTERN AVE, Chicago, IL  41.986921 -87.689778
# 465       5800  N WESTERN AVE, Chicago, IL  41.986921 -87.689778
# ...                                    ...        ...        ...
# 10259   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10260   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10261   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10262   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10264   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10265   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10266   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10267   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10268   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10269   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10270   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10283     1300  N LARAMIE AVE, Chicago, IL  41.904194 -87.756155
# 10284     1300  N LARAMIE AVE, Chicago, IL  41.904194 -87.756155
# 10301       2100  N CANNON DR, Chicago, IL  41.925652 -87.633590
# 10310       2200  N CANNON DR, Chicago, IL  41.921965 -87.632085
# 10311       2200  N CANNON DR, Chicago, IL  41.921965 -87.632085
# 10386   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10387   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10388   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10389   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10390   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10391   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10392   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10413       2100  N CANNON DR, Chicago, IL  41.925652 -87.633590
# 10442      1100  S CALIFORNIA, Chicago, IL  41.868142 -87.696269
# 10443      1100  S CALIFORNIA, Chicago, IL  41.868142 -87.696269
# 10486   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10487   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10488   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10489   1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
#
#        AddressAccuracy  NumMosquitos  WnvPresent  Year Month  Tot_Mos_Species
# 98                   8             1           0  2007    06                2
# 99                   8             1           0  2007    06                2
# 280                  8             1           0  2007    07                3
# 281                  8             2           0  2007    07                3
# 293                  8            50           0  2007    07              143
# 294                  8            35           0  2007    07              143
# 295                  8            50           0  2007    07              143
# 296                  8             8           0  2007    07              143
# 297                  8             1           0  2007    07                9
# 298                  8             8           0  2007    07                9
# 315                  8             1           0  2007    07                3
# 316                  8             2           0  2007    07                3
# 318                  8            37           0  2007    07               51
# 319                  8            14           0  2007    07               51
# 320                  8             8           0  2007    07               12
# 321                  8             4           0  2007    07               12
# 350                  9            50           0  2007    07              189
# 351                  9            50           0  2007    07              189
# 352                  9            39           0  2007    07              189
# 353                  9            50           0  2007    07              189
# 403                  8             3           0  2007    07                4
# 404                  8             1           0  2007    07                4
# 436                  8            29           0  2007    07               30
# 437                  8             1           0  2007    07               30
# 458                  8            15           0  2007    07               34
# 459                  8            19           0  2007    07               34
# 462                  9             1           0  2007    07                3
# 463                  9             2           0  2007    07                3
# 464                  9             2           0  2007    07                3
# 465                  9             1           0  2007    07                3
# ...                ...           ...         ...   ...   ...              ...
# 10259                9            50           0  2013    09              242
# 10260                9            31           0  2013    09              242
# 10261                9            37           0  2013    09              242
# 10262                9            50           0  2013    09              242
# 10264                9            39           1  2013    09               76
# 10265                9            27           0  2013    09              162
# 10266                9            23           0  2013    09              162
# 10267                9            50           0  2013    09              162
# 10268                9            16           0  2013    09              162
# 10269                9            37           1  2013    09               76
# 10270                9            46           0  2013    09              162
# 10283                9            31           0  2013    09               70
# 10284                9            39           0  2013    09               70
# 10301                8             2           0  2013    09               48
# 10310                8             2           0  2013    09               33
# 10311                8            29           0  2013    09               33
# 10386                9            13           1  2013    09               47
# 10387                9             7           1  2013    09               47
# 10388                9            27           1  2013    09               47
# 10389                9            33           0  2013    09               76
# 10390                9            17           0  2013    09               76
# 10391                9            13           0  2013    09               76
# 10392                9            13           0  2013    09               76
# 10413                8             2           0  2013    09               33
# 10442                9             2           0  2013    09               11
# 10443                9             9           0  2013    09               11
# 10486                9            16           0  2013    09               37
# 10487                9             9           0  2013    09               37
# 10488                9            11           0  2013    09               37
# 10489                9             1           0  2013    09               37
#
# [2646 rows x 15 columns]

# %%
df_train = df_train[df_train.duplicated(subset=['Date', 'Trap', 'Species','Tot_Mos_Species','WnvPresent']) == False]
len(df_train)
# Out:
# 8599

# %%
df_train['Species'] = df_train['Species'].apply(lambda x:x.replace('CULEX',''))
df_test['Species'] = df_test['Species'].apply(lambda x:x.replace('CULEX',''))

# %%
df_train[['Species','WnvPresent']].groupby('Species').count().plot(kind='bar',figsize=(8,8))
# Out:
#                    WnvPresent
# Species
#  ERRATICUS                  1
#  PIPIENS                 1994
#  PIPIENS/RESTUANS        3893
#  RESTUANS                2406
#  SALINARIUS                83
#  TARSALIS                   6
#  TERRITANS                216

# %% [markdown]
# Group 'ERRATICUS','SALINARIUS','TARSALIS','TERRTANS' as others

# %%
others = [' ERRATICUS',' SALINARIUS',' TARSALIS',' TERRITANS']
df_train['Species'] = df_train['Species'].apply(lambda x: 'Others' if x in others else x.replace(' ',''))
df_test['Species'] = df_test['Species'].apply(lambda x: 'Others' if x in others else x.replace(' ',''))

# %%
df_train['Species'].value_counts()
# Out:
# PIPIENS/RESTUANS    3893
# RESTUANS            2406
# PIPIENS             1994
# Others               306
# Name: Species, dtype: int64

# %%
df_test['Species'].value_counts()
# Out:
# Others              57398
# PIPIENS/RESTUANS    15359
# RESTUANS            14670
# PIPIENS             14521
# UNSPECIFIED         14345
# Name: Species, dtype: int64

# %% [markdown]
# Test data has an extra category 'UNSPECIFIED' under column Species.

# %%
#Write cleaned datasets out
df_train.to_csv('../datasets/train_cleaned.csv')
df_test.to_csv('../datasets/test_cleaned.csv')

# %%
#Find baseline %
df_train['WnvPresent'].value_counts(normalize=True)
# Out:
# 0    0.946854
# 1    0.053146
# Name: WnvPresent, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.set(font_scale=1.5)
sns.countplot(x='Species', hue='WnvPresent', data=df_train)
plt.xticks(rotation=0)
plt.legend(['West Nile Virus not present', 'West Nile Virus present'], loc=1)
plt.ylabel('Number of Traps with Species')
plt.show()

# %%
fig, axes = plt.subplots(nrows=2,ncols=2,figsize=(20,15))
axes = axes.ravel()
sns.pointplot(x='Month',y='Tot_Mos_Species',hue = 'Species', data = df_train[~df_train['Species'].isin(['Others'])].groupby(['Month','Species'], as_index=False)['Tot_Mos_Species'].sum(),palette='Set2',ax=axes[0])
axes[0].set(xticklabels=['May', 'June', 'July', 'August', 'September', 'October'])
axes[0].set_ylabel('Number of Mosquitos in Trap')

sns.pointplot(x='Month',y='Tot_Mos_Species',hue ='WnvPresent', data = df_train[~df_train['Month'].isin(['05'])].groupby(['Month','WnvPresent'], as_index=False)['Tot_Mos_Species'].sum(),palette='cubehelix',ax=axes[1])
axes[1].set(xticklabels=['June', 'July', 'August', 'September', 'October'])
axes[1].set_ylabel('Number of Mosquitos in Trap')

sns.pointplot(x='Month',y='WnvPresent',hue ='Species', data = df_train[~df_train['Month'].isin(['05'])].groupby(['Month','Species'], as_index=False)['WnvPresent'].sum(),palette='Set2',ax=axes[2])
axes[2].set(xticklabels=['June','July','August','Sept',"Oct"])
axes[2].set_ylabel('Number Of Wnv Present')

plt.show()

# %% [markdown]
# There are the most number of mosquitos in August for Pipens & Pipens/Restuans.

# %% [markdown]
# August seems to be the peak of the Wnv Present case for all years in train data. Comparing with the graph above, the mosquito species Pipen seems to have the most significant impact on Wnv Present by looking at data in August.

# %%
fig, axes = plt.subplots(nrows=2,ncols=2,figsize=(20,15))
axes = axes.ravel()
sns.pointplot(x='Month',y='Tot_Mos_Species',hue ='Year', data = df_train[~df_train['Month'].isin(['05','10'])].groupby(['Month','Year'], as_index=False)['Tot_Mos_Species'].sum(),palette='cubehelix',ax=axes[0])
axes[0].set(xticklabels=['June', 'July', 'August', 'September', 'October'])
axes[0].set_ylabel('Number of Mosquitos in Trap')

sns.pointplot(x='Month',y='WnvPresent',hue ='Year', data = df_train[~df_train['Month'].isin(['05','10'])].groupby(['Month','Year'], as_index=False)['WnvPresent'].sum(),palette='cubehelix',ax=axes[1])
axes[1].set(xticklabels=['June', 'July', 'August', 'September', 'October'])
axes[1].set_ylabel('Number of Wnv Present Case')

sns.pointplot(x='Year',y='Tot_Mos_Species',hue ='Species', data = df_train.groupby(['Year','Species'], as_index=False)['Tot_Mos_Species'].sum(),palette='Set2',ax=axes[2])
axes[2].set(xticklabels=['2007', '2009', '2011', '2013'])
axes[2].set_ylabel('Number Of Mosquito In Trap')

sns.pointplot(x='Year',y='WnvPresent',hue ='Species', data = df_train.groupby(['Year','Species'], as_index=False)['WnvPresent'].sum(),palette='Set2',ax=axes[3])
axes[3].set(xticklabels=['2007', '2009', '2011', '2013'])
axes[3].set_ylabel('Number of Wnv Present Case')

plt.show()

# %% [markdown]
# There is a sharp drop in no. of Wnv Present cases between 2007 to 2009 and sharp increase between 2011 and 2013. Let's investigate the possible reasons.

# %% [markdown]
# There is a sharp drop in PIPENS mosquito from 2007 to 2009 and increase from 2011 to 2013. Combining with the analysis above, it tallys that PIPENS mosquito seems to be a major factor affecting whether Wnv is present.  It is hard to tell whether number of mosquito affects the present of Wnv yet, but the present of the species seems to have an impact on the present of Wnv.

# %%
#Create a list of numerical column together with Species
num_list = []
for i in df_train:
    if df_train[i].dtypes == 'int64' or df_train[i].dtypes == 'float64':
        num_list.append(i)
num_list.append('Species')
num_list
# Out:
# ['Block',
#  'Trap',
#  'Latitude',
#  'Longitude',
#  'AddressAccuracy',
#  'NumMosquitos',
#  'WnvPresent',
#  'Tot_Mos_Species',
#  'Species']

# %%
#plot pair plot
sns.pairplot(df_train[num_list],hue='Species')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
#Narrow down to WnvPresent and Tot_Mos_species
plt.figure(figsize=(15,8))
sns.scatterplot(x='Tot_Mos_Species',y='WnvPresent',hue='Species',data=df_train,alpha=0.5,s=100)
plt.show()

# %% [markdown]
# From the scatte plot above, we can see that Wnv are only present when total number of mosquito by species are below 500, and all of them belong to Species Pipens and Pipes/Restuans. It is a rather weird observation as we should expect Wnv present to increase with total number of mosquito by species. Hence, there are other factors which we can't find out from train dataset. However, we can conclude that the number of mosquito does not have a significant relationship with Wnv Present.
